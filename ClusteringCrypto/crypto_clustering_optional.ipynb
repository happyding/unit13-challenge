# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import os
from dotenv import load_dotenv
#!pip install -U altair

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
load_dotenv()

url = "https://min-api.cryptocompare.com/data/all/coinlist"

api_key = os.getenv("CRYPTOCOMPARE_API_KEY")

payload = {
    "api_key": api_key
}

result = requests.get(url, params=payload).json()

df = pd.DataFrame(result['Data'])

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.
df_transposed = df.T
df_transposed.head()
# Out:
#     Algorithm AssetLaunchDate AssetTokenStatus BlockNumber BlockReward  \
# 42     Scrypt      0000-00-00              N/A           0           0
# 300       N/A      2017-07-01              N/A           0           0
# 365       X11      0000-00-00              N/A           0           0
# 404    Scrypt      0000-00-00              N/A           0           0
# 433       N/A             NaN         Finished         NaN         NaN
#
#     BlockTime BuiltOn   CoinName ContentCreatedOn DecimalPoints  ...  \
# 42          0     NaN    42 Coin       1427211129           NaN  ...
# 300         0     ETH  300 token       1517935016            18  ...
# 365         0     NaN    365Coin       1480032918           NaN  ...
# 404         0     NaN    404Coin       1466100361           NaN  ...
# 433       NaN     NaN  433 Token       1541597321           NaN  ...
#
#     PlatformType ProofType                                             Rating  \
# 42           NaN   PoW/PoS  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 300        token       N/A  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 365          NaN   PoW/PoS  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 404          NaN   PoW/PoS  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
# 433          NaN       N/A  {'Weiss': {'Rating': '', 'TechnologyAdoptionRa...
#
#                            SmartContractAddress SortOrder Sponsored Symbol  \
# 42                                          NaN        34     False     42
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557      2212     False    300
# 365                                         NaN       916     False    365
# 404                                         NaN       602     False    404
# 433                                         NaN      3505     False    433
#
#                                               Taxonomy TotalCoinsMined  \
# 42   {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...               0
# 300  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...             300
# 365  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...               0
# 404  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...               0
# 433  {'Access': '', 'FCA': '', 'FINMA': '', 'Indust...             NaN
#
#                      Url
# 42    /coins/42/overview
# 300  /coins/300/overview
# 365  /coins/365/overview
# 404  /coins/404/overview
# 433  /coins/433/overview
#
# [5 rows x 31 columns]

# %%
# Alternatively, use the provided csv file:
from pathlib import Path
file_path = Path("Resources/crypto_data.csv")
file_df = pd.read_csv(file_path, encoding="ISO-8859-1", index_col=0)
file_df.head()
# Out:
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
columns = ['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']

#coin_list = df_transposed[columns]
#column TotalCoinSupply does not exist in the API return data. so using data file.
coin_list = file_df
list(coin_list.columns)
# Out:
# ['CoinName',
#  'Algorithm',
#  'IsTrading',
#  'ProofType',
#  'TotalCoinsMined',
#  'TotalCoinSupply']

# %%
# Keep only cryptocurrencies that are trading
trading_coin_list = coin_list[coin_list["IsTrading"] == True]
print(trading_coin_list.IsTrading.unique())
trading_coin_list.head()
# Out:
# [ True]
#       CoinName Algorithm  IsTrading ProofType  TotalCoinsMined TotalCoinSupply
# 42     42 Coin    Scrypt       True   PoW/PoS     4.199995e+01              42
# 365    365Coin       X11       True   PoW/PoS              NaN      2300000000
# 404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09       532000000
# 611  SixEleven   SHA-256       True       PoW              NaN          611000
# 808        808   SHA-256       True   PoW/PoS     0.000000e+00               0

# %%
# Keep only cryptocurrencies with a working algorithm
trading_coin_list = trading_coin_list[trading_coin_list['Algorithm'].notna()]
#trading_coin_list.Algorithm.unique()

# %%
# Remove the "IsTrading" column
trading_coin_list = trading_coin_list.drop(['IsTrading'], axis=1).copy()
list(trading_coin_list.columns)
# Out:
# ['CoinName', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']

# %%
# Remove rows with at least 1 null value
trading_coin_list.dropna(inplace = True)
list(trading_coin_list.columns)
# Out:
# ['CoinName', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']

# %%
# Remove rows with cryptocurrencies having no coins mined
trading_coin_list = trading_coin_list[trading_coin_list.TotalCoinsMined > 0]
list(trading_coin_list.columns)
# Out:
# ['CoinName', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']

# %%
# Drop rows where there are 'N/A' text values
trading_coin_list = trading_coin_list[trading_coin_list["CoinName"] != "N/A"]
trading_coin_list = trading_coin_list[trading_coin_list["Algorithm"] != "N/A"] 
trading_coin_list = trading_coin_list[trading_coin_list["ProofType"] != "N/A"] 
trading_coin_list = trading_coin_list[trading_coin_list["TotalCoinsMined"] != "N/A"] 
trading_coin_list = trading_coin_list[trading_coin_list["TotalCoinSupply"] != "N/A"] 
list(trading_coin_list.columns)
# Out:
# ['CoinName', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply']

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coin_names = trading_coin_list['CoinName']

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
trading_coin_list = trading_coin_list.drop(['CoinName'], axis=1).copy()
list(trading_coin_list.columns)
trading_coin_list.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      Scrypt   PoW/PoS     4.199995e+01              42
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337       X13   PoW/PoS     2.927942e+10    314159265359
# BTC    SHA-256       PoW     1.792718e+07        21000000
# ETH     Ethash       PoW     1.076842e+08               0

# %%
# Create dummy variables for text features
trading_coin_list_encoded = pd.get_dummies(trading_coin_list, columns=["Algorithm", "ProofType"])
trading_coin_list_encoded.head()
# Out:
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10    314159265359                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# 404               0                  0                   0                0
# 1337              0                  0                   0                0
# BTC               0                  0                   0                0
# ETH               0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 42                    0                  0              0  ...
# 404                   0                  0              0  ...
# 1337                  0                  0              0  ...
# BTC                   0                  0              0  ...
# ETH                   0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 42                    1                   0                  0
# 404                   1                   0                  0
# 1337                  1                   0                  0
# BTC                   0                   0                  0
# ETH                   0                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 42                     0              0                             0
# 404                    0              0                             0
# 1337                   0              0                             0
# BTC                    0              0                             0
# ETH                    0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 42                           0               0
# 404                          0               0
# 1337                         0               0
# BTC                          0               0
# ETH                          0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 42                                 0                   0
# 404                                0                   0
# 1337                               0                   0
# BTC                                0                   0
# ETH                                0                   0
#
# [5 rows x 98 columns]

# %%
# Standardize data
trading_coin_list_scaled = StandardScaler().fit_transform(trading_coin_list_encoded)
print(trading_coin_list_scaled[0:2])
# Out:
# [[-0.11710817 -0.1528703  -0.0433963  -0.0433963  -0.0433963  -0.06142951
#   -0.07530656 -0.0433963  -0.06142951 -0.06142951 -0.0433963  -0.0433963
#   -0.19245009 -0.06142951 -0.09740465 -0.0433963  -0.11547005 -0.07530656
#   -0.0433963  -0.0433963  -0.15191091 -0.0433963  -0.13118084 -0.0433963
#   -0.0433963  -0.08703883 -0.0433963  -0.0433963  -0.0433963  -0.0433963
#   -0.06142951 -0.0433963  -0.08703883 -0.08703883 -0.08703883 -0.0433963
#   -0.13118084 -0.13840913 -0.13840913 -0.0433963  -0.06142951 -0.0433963
#   -0.07530656 -0.18168574 -0.0433963  -0.0433963  -0.0433963  -0.07530656
#   -0.15826614 -0.31491833 -0.0433963  -0.08703883 -0.07530656 -0.06142951
#    1.38675049 -0.0433963  -0.0433963  -0.06142951 -0.0433963  -0.0433963
#   -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963
#   -0.39879994 -0.0433963  -0.18168574 -0.0433963  -0.08703883 -0.08703883
#   -0.10680283 -0.0433963  -0.13118084 -0.0433963  -0.0433963  -0.0433963
#   -0.0433963  -0.07530656 -0.43911856 -0.0433963  -0.06142951 -0.0433963
#   -0.0433963  -0.89632016 -0.0433963  -0.0433963   1.42222617 -0.0433963
#   -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963
#   -0.0433963  -0.0433963 ]
#  [-0.09396955 -0.145009   -0.0433963  -0.0433963  -0.0433963  -0.06142951
#   -0.07530656 -0.0433963  -0.06142951 -0.06142951 -0.0433963  -0.0433963
#   -0.19245009 -0.06142951 -0.09740465 -0.0433963  -0.11547005 -0.07530656
#   -0.0433963  -0.0433963  -0.15191091 -0.0433963  -0.13118084 -0.0433963
#   -0.0433963  -0.08703883 -0.0433963  -0.0433963  -0.0433963  -0.0433963
#   -0.06142951 -0.0433963  -0.08703883 -0.08703883 -0.08703883 -0.0433963
#   -0.13118084 -0.13840913 -0.13840913 -0.0433963  -0.06142951 -0.0433963
#   -0.07530656 -0.18168574 -0.0433963  -0.0433963  -0.0433963  -0.07530656
#   -0.15826614 -0.31491833 -0.0433963  -0.08703883 -0.07530656 -0.06142951
#    1.38675049 -0.0433963  -0.0433963  -0.06142951 -0.0433963  -0.0433963
#   -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963
#   -0.39879994 -0.0433963  -0.18168574 -0.0433963  -0.08703883 -0.08703883
#   -0.10680283 -0.0433963  -0.13118084 -0.0433963  -0.0433963  -0.0433963
#   -0.0433963  -0.07530656 -0.43911856 -0.0433963  -0.06142951 -0.0433963
#   -0.0433963  -0.89632016 -0.0433963  -0.0433963   1.42222617 -0.0433963
#   -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963  -0.0433963
#   -0.0433963  -0.0433963 ]]

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
# Initialize PCA model
pca = PCA(n_components=3)

# Get two principal components for the data.
trading_coin_list_pca = pca.fit_transform(trading_coin_list_scaled)

# %%
new_coin_names = coin_names.reset_index()
new_coin_names.head()
# Out:
#   index   CoinName
# 0    42    42 Coin
# 1   404    404Coin
# 2  1337  EliteCoin
# 3   BTC    Bitcoin
# 4   ETH   Ethereum

# %%
# Create a DataFrame with the principal components data
df_trading_coin_list_pca = pd.DataFrame(
    data=trading_coin_list_pca, columns=["PC 1", "PC 2", "PC 3"]
)

df_trading_coin_list_pca["Code"] = new_coin_names.iloc[:, 0]
df_trading_coin_list_pca.set_index("Code", inplace = True)
df_trading_coin_list_pca.head()
# Out:
#           PC 1      PC 2      PC 3
# Code
# 42   -0.324781  0.752565 -0.047831
# 404  -0.308085  0.752225 -0.047813
# 1337  2.329099  1.343937 -0.014964
# BTC  -0.152722 -1.183043  0.026044
# ETH  -0.163758 -1.854098  0.055855

# %%
pca.explained_variance_ratio_
# Out:
# array([0.02793044, 0.0213268 , 0.02044379])

# %%
# This is a terrible PCA result. So the encoding of Algorithm and ProofType columns has to be done differently instead of just using dummy values.

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(trading_coin_list_scaled)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# :Curve   [k]   (inertia)

# %%
import altair as alt
alt.Chart(df_elbow,  title="Elbow Curve").mark_line().encode(
    alt.X('k'),
    alt.Y('inertia', stack='center', scale=alt.Scale(domain = [46000,54000]))
).configure_title(
    #labelFontSize=16,
    fontSize=16
)
# Out:
# alt.Chart(...)

# %%
# Not very obvious. The best value looks like 8.

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
new_trading_coin_list = pd.concat([trading_coin_list, df_trading_coin_list_pca, coin_names], axis=1, sort=False)
new_trading_coin_list.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1      PC 2  \
# Code
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.324781  0.752565
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.308085  0.752225
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  2.329099  1.343937
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.152722 -1.183043
# ETH     Ethash       PoW     1.076842e+08               0 -0.163758 -1.854098
#
#           PC 3   CoinName
# Code
# 42   -0.047831    42 Coin
# 404  -0.047813    404Coin
# 1337 -0.014964  EliteCoin
# BTC   0.026044    Bitcoin
# ETH   0.055855   Ethereum

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=8, random_state=0)

# Fit the model
model.fit(trading_coin_list_scaled)

# Predict clusters
predictions = model.predict(trading_coin_list_scaled)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
new_trading_coin_list["class"] = model.labels_
new_trading_coin_list.head(10)
# Out:
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply      PC 1  \
# Code
# 42            Scrypt   PoW/PoS     4.199995e+01              42 -0.324781
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000 -0.308085
# 1337             X13   PoW/PoS     2.927942e+10    314159265359  2.329099
# BTC          SHA-256       PoW     1.792718e+07        21000000 -0.152722
# ETH           Ethash       PoW     1.076842e+08               0 -0.163758
# LTC           Scrypt       PoW     6.303924e+07        84000000 -0.171603
# DASH             X11   PoW/PoS     9.031294e+06        22000000 -0.380471
# XMR   CryptoNight-V7       PoW     1.720114e+07               0 -0.162960
# ETC           Ethash       PoW     1.133597e+08       210000000 -0.162197
# ZEC         Equihash       PoW     7.383056e+06        21000000 -0.149079
#
#           PC 2      PC 3          CoinName  class
# Code
# 42    0.752565 -0.047831           42 Coin      0
# 404   0.752225 -0.047813           404Coin      0
# 1337  1.343937 -0.014964         EliteCoin      2
# BTC  -1.183043  0.026044           Bitcoin      0
# ETH  -1.854098  0.055855          Ethereum      0
# LTC  -1.141649  0.000062          Litecoin      0
# DASH  1.025537 -0.056076              Dash      2
# XMR  -1.963319  0.084614            Monero      0
# ETC  -1.854235  0.055860  Ethereum Classic      0
# ZEC  -1.872791  0.010721             ZCash      0

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters
fig = px.scatter_3d(
    new_trading_coin_list,
    x="PC 1",
    y="PC 2",
    z="PC 3",
    color="class",
    symbol="class",
    width=800,
)
fig.update_layout(legend=dict(x=0, y=1))
fig.show()

# %%
alt.Chart(new_trading_coin_list,  title="Scatter Cluster").mark_circle(size=60).encode(
    alt.X('PC 1'),
    alt.Y('PC 2'),
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'TotalCoinSupply']
).configure_title(
    #labelFontSize=16,
    fontSize=16
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos

tradable_coin_list = new_trading_coin_list.drop(['PC 1', 'PC 2', 'PC 3'], axis=1)

tradable_coin_list = tradable_coin_list[['CoinName', 'Algorithm', 'ProofType', 'TotalCoinsMined', 'TotalCoinSupply', 'class']]

tradable_coin_list.head(10)
# Out:
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# Code
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply  class
# Code
# 42                42      0
# 404        532000000      0
# 1337    314159265359      2
# BTC         21000000      0
# ETH                0      0
# LTC         84000000      0
# DASH        22000000      2
# XMR                0      0
# ETC        210000000      0
# ZEC         21000000      0

# %%
# Print the total number of tradable cryptocurrencies
tradable_coin_list_table = tradable_coin_list.hvplot.table()
tradable_coin_list_table
# Out:
# :Table   [CoinName,Algorithm,ProofType,TotalCoinsMined,TotalCoinSupply,class]

# %%
display(tradable_coin_list)
# Out:
#                 CoinName        Algorithm       ProofType  TotalCoinsMined  \
# Code
# 42               42 Coin           Scrypt         PoW/PoS     4.199995e+01
# 404              404Coin           Scrypt         PoW/PoS     1.055185e+09
# 1337           EliteCoin              X13         PoW/PoS     2.927942e+10
# BTC              Bitcoin          SHA-256             PoW     1.792718e+07
# ETH             Ethereum           Ethash             PoW     1.076842e+08
# LTC             Litecoin           Scrypt             PoW     6.303924e+07
# DASH                Dash              X11         PoW/PoS     9.031294e+06
# XMR               Monero   CryptoNight-V7             PoW     1.720114e+07
# ETC     Ethereum Classic           Ethash             PoW     1.133597e+08
# ZEC                ZCash         Equihash             PoW     7.383056e+06
# BTS            Bitshares          SHA-512             PoS     2.741570e+09
# DGB             DigiByte         Multiple             PoW     1.140622e+10
# BTCD         BitcoinDark          SHA-256         PoW/PoS     1.288862e+06
# XPY              PayCoin          SHA-256             PoS     1.199533e+07
# PRC          ProsperCoin           Scrypt             PoW     5.768310e+06
# KOBO            KoboCoin              X15         PoW/PoS     2.554254e+07
# SPR           Spreadcoin              X11             PoW     1.114973e+07
# ARG             Argentum           Scrypt             PoW     1.220580e+07
# AUR          Aurora Coin           Scrypt         PoW/PoS     1.813510e+07
# BLU             BlueCoin           Scrypt         PoW/PoS     6.354239e+08
# XMY           MyriadCoin         Multiple             PoW     1.688254e+09
# MOON            MoonCoin           Scrypt             PoW     8.800000e+01
# ZET             ZetaCoin          SHA-256             PoW     1.702044e+08
# SXC              SexCoin           Scrypt             PoW     1.289410e+08
# QTL              Quatloo           Scrypt             PoW     7.357795e+06
# ENRG          EnergyCoin           Scrypt         PoW/PoS     1.230628e+08
# QRK            QuarkCoin            Quark             PoW     2.595572e+08
# RIC              Riecoin          Groestl             PoW     4.954859e+07
# DGC         Digitalcoin            Scrypt             PoW     3.344299e+07
# BTB               BitBar           Scrypt         PoW/PoS     4.257948e+04
# ...                  ...              ...             ...              ...
# SMLY          SmileyCoin           Scrypt             PoW     2.958399e+10
# MI            XiaoMiCoin           Scrypt         PoW/PoS     4.043165e+08
# GRS          Groestlcoin          Groestl             PoW     7.329820e+07
# CPC            CapriCoin              X11         PoW/PoS     2.013643e+08
# CLUB            ClubCoin           Scrypt         PoW/PoS     1.036219e+08
# RADS              Radium              PoS             PoS     3.821246e+06
# BTA                 Bata           Scrypt             PoW     5.052556e+06
# PAK              Pakcoin           Scrypt             PoW     6.968446e+07
# CRB           Creditbit               X11  Proof of Trust     1.690102e+07
# OK                OKCash          SHA-256         PoW/PoS     7.467606e+07
# LSK                 Lisk             DPoS            DPoS     1.200121e+08
# XHI               HiCoin           Scrypt             PoS     1.000024e+10
# XWC            WhiteCoin           Scrypt         PoW/PoS     2.520056e+08
# FSC       FriendshipCoin        NeoScrypt         PoW/PoS     1.120385e+06
# J               JoinCoin         Multiple             PoW     3.332922e+06
# TRI       Triangles Coin              X13         PoW/PoS     1.407778e+05
# VOLLAR            Vollar  Equihash+Scrypt             PoW     1.000000e+08
# EOS                  EOS             DPoS            DPoS     1.020545e+09
# RCC        Reality Clash           Ethash             PoW     2.448794e+07
# OXY              Oxycoin             DPoS            DPoS     1.122382e+09
# TCH            TigerCash          SHA-256             PoS     1.000000e+09
# WAVES              Waves       Leased POS            LPoS     1.000000e+08
# PART             Particl              PoS             PoS     9.283138e+06
# BTT           BitTorrent            TRC10            DPoS     9.899887e+11
# NXT                  Nxt              PoS        PoS/LPoS     1.000000e+09
# ZEPH              ZEPHYR          SHA-256            DPoS     2.000000e+09
# GAP              Gapcoin           Scrypt         PoW/PoS     1.493105e+07
# BDX               Beldex      CryptoNight             PoW     9.802226e+08
# ZEN              Horizen         Equihash             PoW     7.296538e+06
# XBC          BitcoinPlus           Scrypt             PoS     1.283270e+05
#
#        TotalCoinSupply  class
# Code
# 42                  42      0
# 404          532000000      0
# 1337      314159265359      2
# BTC           21000000      0
# ETH                  0      0
# LTC           84000000      0
# DASH          22000000      2
# XMR                  0      0
# ETC          210000000      0
# ZEC           21000000      0
# BTS         3600570502      0
# DGB        21000000000      0
# BTCD          22000000      2
# XPY           12500000      0
# PRC           21000000      0
# KOBO         350000000      2
# SPR           20000000      2
# ARG           64000000      0
# AUR           16768584      0
# BLU                  0      0
# XMY         2000000000      0
# MOON      384000000000      0
# ZET          169795588      0
# SXC          250000000      0
# QTL          100000000      0
# ENRG                 0      0
# QRK          247000000      0
# RIC           84000000      0
# DGC           48166000      0
# BTB             500000      0
# ...                ...    ...
# SMLY       50000000000      0
# MI           400000000      0
# GRS          105000000      0
# CPC          208000000      2
# CLUB         160000000      0
# RADS           9000000      0
# BTA            5000000      0
# PAK          182000000      0
# CRB           16504333      2
# OK           105000000      2
# LSK          159918400      0
# XHI        10008835635      0
# XWC          300000000      0
# FSC           60168145      2
# J              2800000      0
# TRI             120000      2
# VOLLAR      2100000000      0
# EOS                  0      0
# RCC           24487944      0
# OXY                  0      0
# TCH         1000000000      0
# WAVES        100000000      6
# PART           8634140      0
# BTT       990000000000      0
# NXT         1000000000      7
# ZEPH        2000000000      0
# GAP          250000000      0
# BDX         1400222610      0
# ZEN           21000000      0
# XBC            1000000      0
#
# [532 rows x 6 columns]

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
import numpy as np

tradable_coin_list.loc[tradable_coin_list.TotalCoinsMined == "0", 'TotalCoinsMined'] = 1
tradable_coin_list['TotalCoinsMined'] = tradable_coin_list['TotalCoinsMined'].astype(float)

tradable_coin_list.loc[tradable_coin_list.TotalCoinSupply == "0", 'TotalCoinSupply'] = 1
tradable_coin_list['TotalCoinSupply'] = tradable_coin_list['TotalCoinSupply'].astype(float)

tradable_coin_list['TotalCoinsMined'] = np.log10(tradable_coin_list['TotalCoinsMined'])
tradable_coin_list['TotalCoinSupply'] = np.log10(tradable_coin_list['TotalCoinSupply'])


tradable_coin_list.head(10)
# Out:
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# Code
# 42             42 Coin          Scrypt   PoW/PoS         1.623249
# 404            404Coin          Scrypt   PoW/PoS         9.023329
# 1337         EliteCoin             X13   PoW/PoS        10.466563
# BTC            Bitcoin         SHA-256       PoW         7.253512
# ETH           Ethereum          Ethash       PoW         8.032152
# LTC           Litecoin          Scrypt       PoW         7.799611
# DASH              Dash             X11   PoW/PoS         6.955750
# XMR             Monero  CryptoNight-V7       PoW         7.235557
# ETC   Ethereum Classic          Ethash       PoW         8.054459
# ZEC              ZCash        Equihash       PoW         6.868236
#
#       TotalCoinSupply  class
# Code
# 42           1.623249      0
# 404          8.725912      0
# 1337        11.497150      2
# BTC          7.322219      0
# ETH          0.000000      0
# LTC          7.924279      0
# DASH         7.342423      2
# XMR          0.000000      0
# ETC          8.322219      0
# ZEC          7.322219      0

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
tradable_coin_list.hvplot.scatter(x="TotalCoinsMined", y="TotalCoinSupply", hover_cols=["CoinName"], by="class")
# Out:
# :NdOverlay   [class]
#    :Scatter   [TotalCoinsMined]   (TotalCoinSupply,CoinName)

# %%
alt.Chart(tradable_coin_list,  title="Tradable Cryptocurrencies").mark_circle(size=60).encode(
    alt.X('TotalCoinsMined'),
    alt.Y('TotalCoinSupply'),
    color='CoinName',
    tooltip=['Algorithm', 'ProofType']
).configure_title(
    #labelFontSize=16,
    fontSize=16
)
# Out:
# alt.Chart(...)
